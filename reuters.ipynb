# %%
import tensorflow as tf

from keras.datasets import reuters
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(
num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 1s 0us/step

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 train_data(1)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
import numpy as np

# %%
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
from keras.utils.np_utils import to_categorical
one_hot_train_labels = to_categorical(train_labels)
one_hot_test_labels = to_categorical(test_labels)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
model.compile(optimizer='rmsprop',
            loss='categorical_crossentropy',
            metrics=['accuracy'])

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]

y_val = one_hot_train_labels[:1000]
partial_y_train = one_hot_train_labels[1000:]
                                       
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 1s 23ms/step - loss: 2.7212 - accuracy: 0.5091 - val_loss: 1.8464 - val_accuracy: 0.6260
# Epoch 2/20
# 16/16 [==============================] - 0s 14ms/step - loss: 1.5355 - accuracy: 0.6847 - val_loss: 1.3840 - val_accuracy: 0.6940
# Epoch 3/20
# 16/16 [==============================] - 0s 14ms/step - loss: 1.1766 - accuracy: 0.7474 - val_loss: 1.1738 - val_accuracy: 0.7460
# Epoch 4/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.9598 - accuracy: 0.7969 - val_loss: 1.0832 - val_accuracy: 0.7600
# Epoch 5/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.7987 - accuracy: 0.8297 - val_loss: 0.9875 - val_accuracy: 0.7870
# Epoch 6/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6652 - accuracy: 0.8582 - val_loss: 0.9409 - val_accuracy: 0.7960
# Epoch 7/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5527 - accuracy: 0.8859 - val_loss: 0.9132 - val_accuracy: 0.7980
# Epoch 8/20
# 16/16 [==============================] - 0s 15ms/step - loss: 0.4686 - accuracy: 0.9024 - val_loss: 0.8498 - val_accuracy: 0.8220
# Epoch 9/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3943 - accuracy: 0.9182 - val_loss: 0.8544 - val_accuracy: 0.8090
# Epoch 10/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3336 - accuracy: 0.9297 - val_loss: 0.8510 - val_accuracy: 0.8230
# Epoch 11/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2877 - accuracy: 0.9391 - val_loss: 0.8409 - val_accuracy: 0.8220
# Epoch 12/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2536 - accuracy: 0.9435 - val_loss: 0.8272 - val_accuracy: 0.8250
# Epoch 13/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2259 - accuracy: 0.9470 - val_loss: 0.8546 - val_accuracy: 0.8180
# Epoch 14/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1989 - accuracy: 0.9496 - val_loss: 0.8674 - val_accuracy: 0.8120
# Epoch 15/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1859 - accuracy: 0.9520 - val_loss: 0.8597 - val_accuracy: 0.8170
# Epoch 16/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1704 - accuracy: 0.9518 - val_loss: 0.9168 - val_accuracy: 0.8040
# Epoch 17/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1598 - accuracy: 0.9539 - val_loss: 0.8586 - val_accuracy: 0.8170
# Epoch 18/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1436 - accuracy: 0.9570 - val_loss: 0.9374 - val_accuracy: 0.8040
# Epoch 19/20
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1408 - accuracy: 0.9554 - val_loss: 0.8872 - val_accuracy: 0.8240
# Epoch 20/20
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1331 - accuracy: 0.9560 - val_loss: 0.9435 - val_accuracy: 0.8090

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()

acc = history.history['acc']
val_acc = history.history['val_acc']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 plt.clf()
# ----> 3 acc = history.history['acc']
#       4 val_acc = history.history['val_acc']
#       6 plt.plot(epochs, acc, 'bo', label='Training acc')
#
# KeyError: 'acc'
